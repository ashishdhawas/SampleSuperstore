# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishdhawas/SampleSuperstore/blob/main/EDA_SampleSuperstore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing all relevant python libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# creating dataframe and store csv data

df = pd.read_csv('/content/drive/MyDrive/SampleSuperstore.csv')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#row,column count of data
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# Lets check if there are any missing values in our data :

# %%
#Lets check if there are any missing values in our data
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# There are no missing values. Hence we can go exploratory analysis part directly.

# %%
#find duplicate values
duplicate_rows = df[df.duplicated()].shape
duplicate_rows
# Out:
# (17, 13)

# %%
#dropping duplicate values
df.drop_duplicates(inplace = True)
num_of_rows = df.shape[0]
num_of_rows
# Out:
# 9977

# %%
# exploring the columns of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
print(df.apply(lambda col: col.unique()))
# Out:
# Ship Mode       [Second Class, Standard Class, First Class, Sa...
# Segment                        [Consumer, Corporate, Home Office]
# Country                                           [United States]
# City            [Henderson, Los Angeles, Fort Lauderdale, Conc...
# State           [Kentucky, California, Florida, North Carolina...
# Postal Code     [42420, 90036, 33311, 90032, 28027, 98103, 761...
# Region                               [South, West, Central, East]
# Category                 [Furniture, Office Supplies, Technology]
# Sub-Category    [Bookcases, Chairs, Labels, Tables, Storage, F...
# Sales           [261.96, 731.94, 14.62, 957.5775, 22.368, 48.8...
# Quantity          [2, 3, 5, 7, 4, 6, 9, 1, 8, 14, 11, 13, 10, 12]
# Discount        [0.0, 0.45, 0.2, 0.8, 0.3, 0.5, 0.7, 0.6, 0.32...
# Profit          [41.9136, 219.582, 6.8714, -383.031, 2.5164, 1...
# dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States    9977
# Name: Country, dtype: int64

# %% [markdown]
# Clearly the data is for United States country only, so we can drop the 'Country' column as we dont need any analysis to be done based on it.

# %%
#dropping Country column
df=df.drop('Country',axis=1)
df.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
#row,column count of data
df.shape
# Out:
# (9977, 12)

# %% [markdown]
# Exploratory Analysis :

# %% [markdown]
# Lets look at the product categories available in our data :

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# There are 3 categories in our data : 'Furniture', 'Office Supplies' and 'Technology'.

# %%
# number of products in each category 
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
#plot of products in each category
plt.figure(figsize=(10,8))
df['Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
#number of products in each sub-category
df['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
# plot of products in each sub-category
plt.figure(figsize=(10,8))
df['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %% [markdown]
# Total Profit and Sales per Sub-Category :

# %%
plt.figure(figsize=(8,6))
df.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar(figsize=(12,8))
plt.title('Total Profit and Sales per Sub-Category')
plt.show();
# Out:
# <ipython-input-23-6331f1b493e0>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar(figsize=(12,8))

# %%
#Count of Sub-Category region wise
plt.figure(figsize=(12,8))
sns.countplot(x="Sub-Category", hue="Region", data=df)
plt.show()

# %% [markdown]
# People residing in Western part of US tend to order more from superstore.

# %% [markdown]
# The weak areas where we can work to make more profit ?

# %% [markdown]
# Checking the Profit based on the Region :

# %%
df.groupby('Region')['Profit'].agg(['sum']).sort_values(['sum'], ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# The Profit is maximum in the Western Region of the country and minimum in the Central Region of the country.

# %% [markdown]
# We now move on to checking the Profit earned in each the State :

# %%
df.groupby('State')['Profit'].agg(['sum']).sort_values(['sum'], 
                                                         ascending=False).plot.bar(figsize=(12,8));

# %% [markdown]
# We can see that the maximum profits comes from the State of California followed by New York. And the minimum profits comes from the States of Texas followed by Ohio and Pensylvania.

# %% [markdown]
# Top 10 cities in US with high profits sum :

# %%
df.groupby('City')['Profit'].agg(['sum']).sort_values(['sum'],ascending=False)[:10].plot.bar(figsize=(12,8));

# %% [markdown]
# The maximum profits in all the Cities comes from the New York City followed by Los Angeles and Seattle.

# %% [markdown]
# Top 10 non profitable cities in US :

# %%
df.groupby('City')['Profit'].agg(['sum']).sort_values(['sum'], ascending=False)[-10:].plot.bar(figsize=(10,8));

# %% [markdown]
# The minimum profits in all the Cities comes from Philadelphia followed by Houston City.

# %% [markdown]
# Total Profit VS Sub Category

# %%
df.groupby('Sub-Category')['Profit'].agg(['sum']).sort_values(['sum'], ascending=False).plot.bar(figsize=(10,8));

# %% [markdown]
# The maximum profit was earned by selling the copiers and the highest losses are incurred in selling the Tables, Bookcases and Supplies respectively.

# %% [markdown]
# Profit VS Shipping Mode

# %%
df.groupby('Ship Mode')['Profit'].agg(['sum']).sort_values(['sum'], ascending=False).plot.bar(figsize=(10,6));

# %% [markdown]
# This shows that the Standard Shipping is the most profitable Shipping Mode in all the Categories (>160 000).

# %% [markdown]
# Profit in Each Segment

# %%
df.groupby('Segment')['Profit'].agg(['sum']).sort_values(['sum'], ascending=False).plot.bar(figsize=(10,6));

# %% [markdown]
# The most profitable Segment is Consumers followed by Corporate and Home Office.

# %% [markdown]
# Profit VS Category

# %%
df.groupby('Category')['Profit'].agg(['sum']).sort_values(['sum'], ascending=False).plot.bar(figsize=(10,6));

# %% [markdown]
# We can see that the Technology is the most profitable category, followed by Office Supplies and Furniture.
